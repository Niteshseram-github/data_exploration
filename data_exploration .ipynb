# %%
#importing pandas
import pandas as pd
import matplotlib.pyplot as plot
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Reading Data

# %%
# reading the csv file

df = pd.read_csv("data.csv")

# %%
#seeing the dimension of the file

df.shape
# Out:
# (891, 12)

# %%
#seeing the names of varibales in the dataset

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#seeing the top 5 rows 

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Variable Identification

# %%
#variables identification
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Univariate Analysis of Continuous Variables

# %%
#using the describe function on the continuous variables
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#plotting the histogram of the age variable
df['Age'].plot.hist()

# %%
#plotting boxplot for the age variable
df['Age'].plot.box()

# %% [markdown]
# # Univariate analysis for Categorical variables

# %%
#Creating frequency table for the categorical variable Sex
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#Creating percentages from frequencies
df['Sex'].value_counts()/len(df['Sex'])
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
#Creating bar plot for sex frequencies
df['Sex'].value_counts().plot.bar()

# %%
#Creating bar plot for percentages 
(df['Sex'].value_counts()/len(df['Sex'])).plot.bar()

# %% [markdown]
# # Continuous-Continuous Bivariate Analysis

# %%
df.plot.scatter('Age','Fare')

# %%
#finding the correlation between all the variables in the dataframe
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#finding correlation between the Variable Age and Fare
df['Age'].corr(df['Fare'])
# Out:
# 0.09606669176903887

# %% [markdown]
# # Categorical-Continuous Bivariate Analysis

# %%
#finding mean age for male and female and plotting it in bar plot
df.groupby('Sex')['Age'].mean().plot.bar()

# %%
#importing scipy library for ttest
from scipy.stats import ttest_ind

# %%
males=df[df['Sex']=='male']

# %%
females=df[df['Sex']=='female']

# %%
#calculating p value and nan_policy='omit' means to omit the values with null because ttest_ind doesn't support null value
ttest_ind(males['Age'],females['Age'],nan_policy='omit')
# Out:
# Ttest_indResult(statistic=2.499206354920835, pvalue=0.012671296797014266)

# %% [markdown]
# # Categorical-Categorical Bivariate Analysis

# %%
#creating two-way table
pd.crosstab(df['Sex'],df['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
#importing lib for chi square test
from scipy.stats import chi2_contingency

# %%
chi2_contingency(pd.crosstab(df['Sex'],df['Survived']))
# Out:
# (260.71702016732104,
#  1.1973570627755645e-58,
#  1,
#  array([[193.47474747, 120.52525253],
#         [355.52525253, 221.47474747]]))

# %% [markdown]
# # Treating missing values

# %%
#checking missing values for continuous variables
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#checking missing values for variables
#True-value missing False- Value is present
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
#print number of missing values for each attribute
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#dropping all rows wherever there are missing values
#the command below doesnt modify the orginal dataframe
#To do that use command df=df.dropna()
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
#check if there are any missing values after dropping all the rows with missing values
df.dropna().isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#dropping rows where all the entries are missing
df.dropna(how="all")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#dropping columns with any missing values
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#check dropping columns with any missing values
df.dropna(axis=1).shape
# Out:
# (891, 9)

# %%
#dropping columns where all the entries are missing
df.dropna(axis=1,how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#filling all the missing values in dataframe with 0
#the command belowe doesnt alter the original dataframe
#to do that use df.fillna(0,inplace=True)
df.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#filling missing value in the column with 0
df['Age'].fillna(0)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       0.0
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      0.0
# 18     31.0
# 19      0.0
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      0.0
# 27     19.0
# 28      0.0
# 29      0.0
#        ...
# 861    21.0
# 862    48.0
# 863     0.0
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     0.0
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     0.0
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     0.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#filling missing value in column Age with value mean age
df['Age'].fillna(df['Age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# 5      29.699118
# 6      54.000000
# 7       2.000000
# 8      27.000000
# 9      14.000000
# 10      4.000000
# 11     58.000000
# 12     20.000000
# 13     39.000000
# 14     14.000000
# 15     55.000000
# 16      2.000000
# 17     29.699118
# 18     31.000000
# 19     29.699118
# 20     35.000000
# 21     34.000000
# 22     15.000000
# 23     28.000000
# 24      8.000000
# 25     38.000000
# 26     29.699118
# 27     19.000000
# 28     29.699118
# 29     29.699118
#          ...
# 861    21.000000
# 862    48.000000
# 863    29.699118
# 864    24.000000
# 865    42.000000
# 866    27.000000
# 867    31.000000
# 868    29.699118
# 869     4.000000
# 870    26.000000
# 871    47.000000
# 872    33.000000
# 873    47.000000
# 874    28.000000
# 875    15.000000
# 876    20.000000
# 877    19.000000
# 878    29.699118
# 879    56.000000
# 880    25.000000
# 881    33.000000
# ...

# %% [markdown]
# # Univariate Outliers Detection

# %%
#hecking outliers for single variablem
df['Age'].plot.box()

# %% [markdown]
# # Bivariate Outliers Detection

# %%
#plotting scatter plot for two variables
df.plot.scatter('Age','Fare')

# %% [markdown]
# # Removing outliers from the dataset

# %%
#removing outliers from Fare 
df=df[df['Fare']<300]
df.plot.scatter('Age','Fare')

# %% [markdown]
# # Replacing outliers in age with mean age

# %%
df.loc[df['Age']>65,'Age']=np.mean(df['Age'])
df['Age'].plot.box()

# %% [markdown]
# # Variable Transformation

# %%
#lets first check the distribution of Age varaible
df['Age'].plot.hist()

# %%
#since the above distribution is right skewed, lets first do log transformation
np.log(df['Age']).plot.hist()

# %%
#we are not satisfy with above result because we want normal distribution, so lets do cube root tranformation
np.power(df['Age'],1/3).plot.hist()

# %%
#lets check out square root and we can see its better than the above tranformation
np.sqrt(df['Age']).plot.hist()

# %%
#binning tranformation to convert continuous variable to categorical variable
bins=[0,15,80]
group=['Child','Adult']
#creating a Type attribute according to group
df['Type']=pd.cut(df['Age'],bins,labels=group)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Type
# 0      0         A/5 21171   7.2500   NaN        S  Adult
# 1      0          PC 17599  71.2833   C85        C  Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Adult
# 3      0            113803  53.1000  C123        S  Adult
# ...

# %%
df['Type'].value_counts()
# Out:
# Adult    628
# Child     83
# Name: Type, dtype: int64
